# %% [markdown]
# ### *First let's import the packages we will use in this project*

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %% [markdown]
# ### *Importing Dataset*

# %%
df = pd.read_csv('/content/movies.csv')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %% [markdown]
# ### *Drop rows with missing data*

# %%
df = df.dropna(axis=0)

df.head(2)
# Out:
#               name rating      genre  year  score     votes         director  \
# 0      The Shining      R      Drama  1980    8.4  927000.0  Stanley Kubrick
# 1  The Blue Lagoon      R  Adventure  1980    5.8   65000.0   Randal Kleiser
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
#
#         gross            company  runtime
# 0  46998772.0       Warner Bros.    146.0
# 1  58853106.0  Columbia Pictures    104.0

# %% [markdown]
# ### *Verify we have no more missing values*

# %%
for col in df.columns:
    missing = df[col].isnull()
    print('{} - {} Missing Values'.format(col, missing.sum()) )
# Out:
# name - 0 Missing Values
# rating - 0 Missing Values
# genre - 0 Missing Values
# year - 0 Missing Values
# score - 0 Missing Values
# votes - 0 Missing Values
# director - 0 Missing Values
# writer - 0 Missing Values
# star - 0 Missing Values
# country - 0 Missing Values
# budget - 0 Missing Values
# gross - 0 Missing Values
# company - 0 Missing Values
# runtime - 0 Missing Values

# %% [markdown]
# ### *Check datatypes for of our dataframe*

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %% [markdown]
# ### *Remove unecessary decimals by changing datatype*

# %%
df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

df['votes'] = df['gross'].astype('int64')

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#    score      votes         director                   writer            star  \
# 0    8.4   46998772  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8   58853106   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2    8.7  538375067   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3    7.7   83453539     Jim Abrahams             Jim Abrahams     Robert Hays
# 4    7.3   39846344     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
# ...

# %% [markdown]
# ### *Check for duplicate rows*

# %%
df.duplicated().value_counts()
# Out:
# False    5421
# dtype: int64

# %% [markdown]
# ### *Visualize budget vs gross earnings using seaborn regplot*

# %%
plt.figure(figsize=(18,10))
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'red'}, line_kws={'color':'blue'})

# %% [markdown]
# ### *Visualize correlations between budget and gross income using a scatter plot*

# %%
plt.figure(figsize=(18, 10))
plt.scatter(x=df['budget'], y=df['gross'])
plt.title("Budget vs Gross Earnings")
plt.xlabel('Budget For Film')
plt.ylabel('Gross Earnings')
# Out:
# Text(0, 0.5, 'Gross Earnings')

# %% [markdown]
# ### *Visualize correlations between Score and gross income using a scatter plot*

# %%
plt.figure(figsize=(18, 10))
plt.scatter(x=df['score'], y=df['gross'])
plt.title("Score vs Gross Earnings")
plt.xlabel('Score of Film')
plt.ylabel('Gross Earnings')
# Out:
# Text(0, 0.5, 'Gross Earnings')

# %% [markdown]
# ### *Correlation Matrix between all numeric columns*

# %%
df.corr(method ='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.274321  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.222556  0.072001  0.222556  0.414068
# votes    0.274321  0.222556  1.000000  0.740247  1.000000  0.275796
# budget   0.327722  0.072001  0.740247  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  1.000000  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.275796  0.318695  0.275796  1.000000

# %%
df.corr(method ='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.239539  0.220833  0.239539  0.064824
# score    0.039389  1.000000  0.124943 -0.006406  0.124943  0.292254
# votes    0.239539  0.124943  1.000000  0.512057  1.000000  0.176979
# budget   0.220833 -0.006406  0.512057  1.000000  0.512057  0.231278
# gross    0.239539  0.124943  1.000000  0.512057  1.000000  0.176979
# runtime  0.064824  0.292254  0.176979  0.231278  0.176979  1.000000

# %%
df.corr(method ='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057741  0.351045  0.312886  0.351045  0.095444
# score    0.057741  1.000000  0.183192 -0.009971  0.183192  0.412155
# votes    0.351045  0.183192  1.000000  0.692958  1.000000  0.257400
# budget   0.312886 -0.009971  0.692958  1.000000  0.692958  0.330794
# gross    0.351045  0.183192  1.000000  0.692958  1.000000  0.257400
# runtime  0.095444  0.412155  0.257400  0.330794  0.257400  1.000000

# %% [markdown]
# ### *Look at dataframe correlation in a matrix*

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation matrix for Numeric Features")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %% [markdown]
# ### *Using factorize - this assigns a random numeric value for each unique categorical value*

# %%
df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#               name    rating     genre      year     score     votes  \
# name      1.000000  0.169808  0.028413  0.965461 -0.020083  0.967925
# rating    0.169808  1.000000 -0.116507  0.179456  0.036114  0.172703
# genre     0.028413 -0.116507  1.000000  0.031765 -0.027402  0.032033
# year      0.965461  0.179456  0.031765  1.000000 -0.014594  0.996371
# score    -0.020083  0.036114 -0.027402 -0.014594  1.000000 -0.015744
# votes     0.967925  0.172703  0.032033  0.996371 -0.015744  1.000000
# director  0.725411  0.096014  0.036671  0.747785 -0.006583  0.751737
# writer    0.791872  0.128909  0.033975  0.812386 -0.021538  0.811356
# star      0.695124  0.115694  0.045497  0.719373  0.015108  0.720811
# country   0.098110 -0.004547 -0.003314  0.095073  0.016567  0.094820
# budget    0.288955  0.203698  0.020893  0.319135 -0.005493  0.305284
# gross     0.967925  0.172703  0.032033  0.996371 -0.015744  1.000000
# company   0.535369 -0.026286  0.015127  0.537731 -0.008555  0.545924
# ...

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation matrix for Movies")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name     name       1.000000
#          rating     0.169808
#          genre      0.028413
#          year       0.965461
#          score     -0.020083
#                       ...
# runtime  country    0.040813
#          budget     0.134894
#          gross      0.047728
#          company   -0.010695
#          runtime    1.000000
# Length: 196, dtype: float64

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name     name       1.000000
#          rating     0.169808
#          genre      0.028413
#          year       0.965461
#          score     -0.020083
#                       ...
# runtime  country    0.040813
#          budget     0.134894
#          gross      0.047728
#          company   -0.010695
#          runtime    1.000000
# Length: 196, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# rating   genre     -0.116507
# genre    rating    -0.116507
# budget   company   -0.053573
# company  budget    -0.053573
# genre    score     -0.027402
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 196, dtype: float64

# %% [markdown]
# ### *We can now take a look at the ones that have a high correlation (> 0.5)*

# %%
strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# company  name       0.535369
# name     company    0.535369
# year     company    0.537731
# company  year       0.537731
#          votes      0.545924
#                       ...
# year     year       1.000000
# genre    genre      1.000000
# rating   rating     1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# Length: 64, dtype: float64

# %% [markdown]
# ### *Looking at the top 15 compaies by gross revenue*

# %%
CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 54610959970
# Universal Pictures           51241105418
# Columbia Pictures            42356430218
# Paramount Pictures           40021704691
# Twentieth Century Fox        39542573303
# Walt Disney Pictures         35833650748
# New Line Cinema              19612851164
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Dreamworks Pictures          11593807697
# Touchstone Pictures          10664679494
# Metro-Goldwyn-Mayer (MGM)     8937010092
# Summit Entertainment          8318570396
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7243673721
# Name: gross, dtype: int64

# %%
df.groupby(['company', 'year'])[["gross"]].sum()
# Out:
#                                               gross
# company                             year
# "DIA" Productions GmbH & Co. KG     2003   44350926
# "Weathering With You" Film Partners 2019  193457467
# .406 Production                     1996      10580
# 1492 Pictures                       1996  129832389
#                                     1999   87423861
# ...                                             ...
# erbp                                2013     587174
# i am OTHER                          2015   17986781
# i5 Films                            2001   10031529
# micro_scope                         2010    7099598
# thefyzz                             2017   62198461
#
# [2987 rows x 1 columns]

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Warner Bros.           2005    2688767210
# Name: gross, dtype: int64

# %%
CompanyGrossSum = df.groupby(['company'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 54610959970
# Universal Pictures           51241105418
# Columbia Pictures            42356430218
# Paramount Pictures           40021704691
# Twentieth Century Fox        39542573303
# Walt Disney Pictures         35833650748
# New Line Cinema              19612851164
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Dreamworks Pictures          11593807697
# Touchstone Pictures          10664679494
# Metro-Goldwyn-Mayer (MGM)     8937010092
# Summit Entertainment          8318570396
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7243673721
# Name: gross, dtype: int64

# %%
plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
# ...

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  score      votes  director  writer  star  \
# 0     4692       6      6  1980    8.4   46998772      1795    2832   699
# 1     3929       6      1  1980    5.8   58853106      1578    1158   214
# 2     3641       4      0  1980    8.7  538375067       757    1818  1157
# 3      204       4      4  1980    7.7   83453539       889    1413  1474
# 4      732       6      4  1980    7.3   39846344       719     351   271
# ...    ...     ...    ...   ...    ...        ...       ...     ...   ...
# 7648   415       6      0  2020    6.6  426505244        16    2390  1812
# 7649  3556       4      0  2020    6.5  319715683       852    2309   147
# 7650  1153       4      1  2020    5.6  245487753      1809    2827  1470
# 7651  3978       4      1  2020    6.8  111105497       294    2091   640
# 7652  4090       3      0  2020    6.8  461421559       746    1184  1839
#
#       country     budget      gross  company  runtime
# ...

# %%
df_numerized.corr(method='pearson')
# Out:
#               name    rating     genre      year     score     votes  \
# name      1.000000 -0.029234  0.010996  0.025542  0.014450  0.005639
# rating   -0.029234  1.000000  0.147796  0.019499  0.065983 -0.181906
# genre     0.010996  0.147796  1.000000 -0.073167  0.035106 -0.244101
# year      0.025542  0.019499 -0.073167  1.000000  0.056386  0.274321
# score     0.014450  0.065983  0.035106  0.056386  1.000000  0.222556
# votes     0.005639 -0.181906 -0.244101  0.274321  0.222556  1.000000
# director  0.015246  0.014656 -0.008553 -0.038354  0.005413 -0.029560
# writer    0.012880 -0.003149  0.017578 -0.025908  0.012843 -0.035885
# star     -0.006882  0.009196  0.003341 -0.032157  0.007296 -0.000004
# country  -0.025490  0.008230 -0.009164 -0.066748 -0.043051  0.060078
# budget    0.023392 -0.203946 -0.368523  0.327722  0.072001  0.740247
# gross     0.005639 -0.181906 -0.244101  0.274321  0.222556  1.000000
# company   0.021697 -0.092357 -0.071334 -0.014333  0.020656  0.149553
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
sns.swarmplot(x="rating", y="gross", data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 23.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 63.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 77.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 84.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.stripplot(x="rating", y="gross", data=df)
